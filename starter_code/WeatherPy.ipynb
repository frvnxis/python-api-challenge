# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os
from dotenv import load_dotenv
load_dotenv()
# Impor the OpenWeatherMap API key
weather_key = os.getenv("weather_key")
type (weather_key)

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# Python-dotenv could not parse statement starting at line 6

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_key
print(url)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + "Boston"
    print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        # Make a 'Get' request for the city weather.
        city_weather = requests.get(city_url)
        city_weather

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        
        # Create an endpoint URL for a city.
        city_url = url + "&q=" + "Boston"
        city_weather = requests.get(city_url)
        city_weather
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 1 | mataura
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 1 | tuatapere
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 1 | hobart
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 1 | longyearbyen
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 1 | atuona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 1 | koumac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 1 | upernavik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 1 | bubaque
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 1 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 1 | rikitea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 1 | provideniya
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 1 | hilo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 1 | arraial do cabo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 1 | bluff
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 1 | airai
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 1 | sabha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 1 | rehoboth
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 1 | severo-kurilsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 1 | hobyo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 1 | busselton
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 1 | vila velha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 1 | dikson
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 1 | mahebourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 24 of Set 1 | padang
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 25 of Set 1 | kuching
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 26 of Set 1 | kulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 28 of Set 1 | manta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 29 of Set 1 | cidreira
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 30 of Set 1 | kharitonovo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 31 of Set 1 | mar del plata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 32 of Set 1 | coihaique
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 33 of Set 1 | ohara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 34 of Set 1 | gangotri
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 1 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 1 | barrow
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 1 | iqaluit
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 1 | abu dhabi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 1 | alberton
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 1 | esperance
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 1 | turan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 1 | chokurdakh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 1 | osorio
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 1 | torbay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 1 | araouane
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 1 | kavaratti
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 1 | bengkulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 1 | carnarvon
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 50 of Set 1 | madoc
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 2 | punta arenas
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 2 | scarborough
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 2 | boca do acre
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 2 | hermanus
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 2 | nykobing
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 2 | bowen
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 2 | cherskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 2 | faya
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 2 | victoria
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 2 | podgornoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 2 | ballybofey
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 2 | phangnga
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 2 | tiksi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 2 | riviere-au-renard
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 2 | sao filipe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 2 | awjilah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 2 | norman wells
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 2 | maceio
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 2 | adrar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 2 | jamestown
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 2 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 2 | jinchang
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 24 of Set 2 | rungata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 25 of Set 2 | sorong
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 26 of Set 2 | laizhou
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 27 of Set 2 | jorpeland
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 28 of Set 2 | palmerston
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 29 of Set 2 | imbituba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 30 of Set 2 | udankudi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 31 of Set 2 | kununurra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 32 of Set 2 | onufriyivka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 33 of Set 2 | opuwo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 34 of Set 2 | saskylakh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 35 of Set 2 | ancud
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 2 | aklavik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 2 | devyatka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 2 | butaritari
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 2 | kapaa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 2 | evansville
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 2 | nandigama
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 2 | avarua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 2 | qaanaaq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 2 | golkoy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 2 | puerto escondido
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 2 | vilyuysk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 2 | saint-pierre
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 2 | batagay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 2 | nueva londres
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 3 | sao joao da barra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 3 | dongying
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 3 | hithadhoo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 3 | bredasdorp
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 3 | port elizabeth
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 3 | new norfolk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 3 | ruthin
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 3 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 3 | angoram
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 3 | abu kamal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 3 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 3 | port alfred
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 3 | east london
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 3 | saint-philippe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 3 | mayumba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 3 | ushuaia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 3 | marawi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 3 | olafsvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 3 | pangkalanbuun
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 3 | la ronge
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 3 | hambantota
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 3 | petranka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 24 of Set 3 | pevek
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 25 of Set 3 | itupiranga
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 26 of Set 3 | sai buri
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 27 of Set 3 | malakal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 28 of Set 3 | coquimbo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 29 of Set 3 | sayanogorsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 30 of Set 3 | dryden
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 31 of Set 3 | vaini
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 32 of Set 3 | ipameri
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 33 of Set 3 | puerto ayora
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 34 of Set 3 | cape town
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 35 of Set 3 | lorengau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 3 | leh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 3 | cockburn town
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 3 | port lincoln
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 3 | wanning
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 3 | narsaq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 3 | formoso do araguaia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 3 | borlange
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 3 | bethanien
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 3 | dogondoutchi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 3 | barcelona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 3 | albany
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 3 | knysna
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 3 | yellowknife
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 4 | bethel
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 4 | perivolion
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 4 | lebu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 4 | sisimiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 4 | lasem
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 4 | shakawe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 4 | ubatuba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 4 | shimoda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 4 | a
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 4 | terney
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 4 | ahipara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 4 | shitanjing
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 4 | georgiyevka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 4 | mindelo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 4 | saquarema
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 4 | rantepao
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 4 | altamira
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 4 | port moresby
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 4 | georgetown
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 4 | yulara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 4 | harrismith
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 4 | kibala
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 4 | varzea da palma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 4 | bilibino
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 24 of Set 4 | ballaghaderreen
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 25 of Set 4 | aripuana
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 26 of Set 4 | hami
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 27 of Set 4 | flin flon
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 28 of Set 4 | tasiilaq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 29 of Set 4 | narrabri
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 30 of Set 4 | kifri
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 31 of Set 4 | kaseda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 32 of Set 4 | sorvag
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 33 of Set 4 | mount gambier
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 34 of Set 4 | voznesenskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 35 of Set 4 | dalby
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 4 | voh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 4 | praia da vitoria
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 4 | kegayli
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 4 | namatanai
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 4 | broome
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 4 | makaha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 4 | harper
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 4 | poum
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 4 | arlit
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 4 | flinders
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 4 | roald
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 4 | margate
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 4 | samarai
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 4 | faanui
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 5 | benin
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 5 | kangaatsiaq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 5 | tazovskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 5 | aylmer
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 5 | karratha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 5 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 5 | arman
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 5 | saldanha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 5 | lazaro cardenas
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 5 | qasigiannguit
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 5 | nishihara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 5 | diamantino
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 5 | yar-sale
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 5 | plettenberg bay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 5 | kenora
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 5 | pasinler
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 5 | russell
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 5 | touros
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 5 | nikolskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 5 | atar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 5 | oktyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 5 | harer
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 5 | qaqortoq
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 5 | palmer
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 24 of Set 5 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 25 of Set 5 | oistins
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 26 of Set 5 | mayo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 27 of Set 5 | ribeira grande
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 28 of Set 5 | churapcha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 29 of Set 5 | ukiah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 30 of Set 5 | oga
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 31 of Set 5 | matara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 32 of Set 5 | lompoc
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 33 of Set 5 | honavar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 34 of Set 5 | ruidoso
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 35 of Set 5 | newport
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 5 | twentynine palms
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 5 | deputatskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 5 | kaitangata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 5 | haines junction
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 5 | thompson
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 5 | muros
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 5 | castro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 5 | minab
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 5 | zabol
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 5 | gizo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 5 | mehamn
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 5 | eyrarbakki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 5 | ishigaki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 5 | ambilobe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 6 | berlevag
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 6 | nelas
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 6 | siparia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 6 | manuk mangkaw
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 6 | mamou
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 6 | sahrak
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 6 | zhigansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 6 | ketchikan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 6 | san carlos de bariloche
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 6 | baykit
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 6 | bathsheba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 6 | bambous virieux
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 6 | nome
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 6 | matthews
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 6 | mastic beach
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 6 | manzhouli
# ...
# Processing Record 35 of Set 11 | zalantun
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 11 | kokoda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 11 | mlonggo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 11 | puerto leguizamo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 11 | puerto narino
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 11 | ucluelet
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 11 | boende
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 11 | antofagasta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 11 | mazyr
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 11 | kollumerland
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 11 | zhanaozen
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 11 | cordele
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 11 | maragogi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 11 | merritt island
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 11 | ponta delgada
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 12 | guayaramerin
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 12 | winston-salem
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 12 | novovasylivka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 12 | mantua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 12 | raudeberg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 12 | santa rosa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 12 | ulladulla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 12 | bandarbeyla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 12 | vitim
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 12 | ocean city
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 12 | honiara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 12 | rovaniemi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 12 | languyan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 12 | rhede
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 12 | kirakira
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 12 | itarema
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 12 | stornoway
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 12 | haibowan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 12 | monte santo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 12 | launceston
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 12 | mumford
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 12 | mtwara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 12 | sitka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 12 | saveh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 24 of Set 12 | malangali
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 25 of Set 12 | gangakher
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 26 of Set 12 | zaraysk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 27 of Set 12 | scalea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 28 of Set 12 | urucara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 29 of Set 12 | udachnyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 30 of Set 12 | henties bay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 31 of Set 12 | luebo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 32 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 33 of Set 12 | green river
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 35 of Set 12 | yanam
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 36 of Set 12 | saraland
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 37 of Set 12 | yirol
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 38 of Set 12 | vesele
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 39 of Set 12 | utiroa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 40 of Set 12 | gua musang
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 41 of Set 12 | aracati
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 42 of Set 12 | masvingo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 43 of Set 12 | morros
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 44 of Set 12 | callaguip
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 45 of Set 12 | leshukonskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 46 of Set 12 | sola
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 47 of Set 12 | mezen
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 48 of Set 12 | rafai
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 49 of Set 12 | galitsy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 0 of Set 13 | xinmin
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 1 of Set 13 | donskoy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 2 of Set 13 | pecos
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 3 of Set 13 | khandyga
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 4 of Set 13 | ayan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 5 of Set 13 | nautla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 6 of Set 13 | katobu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 7 of Set 13 | egvekinot
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 8 of Set 13 | tubuala
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 9 of Set 13 | saint anthony
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 10 of Set 13 | havoysund
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 11 of Set 13 | ixtapa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 12 of Set 13 | vikhorevka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 13 of Set 13 | popondetta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 14 of Set 13 | salym
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 15 of Set 13 | quelimane
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 16 of Set 13 | ialibu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 17 of Set 13 | mahanje
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 18 of Set 13 | dallas
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 19 of Set 13 | karasjok
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 20 of Set 13 | kalabo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 21 of Set 13 | vao
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 22 of Set 13 | grakhovo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8745f392759c43f59474dc214e002e8a&q=Boston
# Processing Record 23 of Set 13 | natal
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"base":"stations","main":{"temp":31.73,"feels_like":29.01,"temp_min":28.17,"temp_max":34.21,"pressure":1022,"humidity":86},"visibility":10000,"wind":{"speed":3,"deg":281,"gust":8.99},"clouds":{"all":25},"dt":1674626360,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1674648271,"sunset":1674683293},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the text of the 'get' request in JSON format
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 31.73,
#   'feels_like': 29.01,
#   'temp_min': 28.17,
#   'temp_max': 34.21,
#   'pressure': 1022,
#   'humidity': 86},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 281, 'gust': 8.99},
#  'clouds': {'all': 25},
#  'dt': 1674626360,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1674648271,
#   'sunset': 1674683293},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Display sample Json data
boston_data = city_weather.json()
boston_data["dt"]
boston_data["coord"]["lat"]
# Out:
# 42.3584

# %%
# get lat, long, max temp, humidity, cloudiness, and wind speed:

lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 34.21 86 25 3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2023, 1, 25, 5, 59, 20)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | koumac
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | bubaque
# Processing Record 9 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | sabha
# Processing Record 17 of Set 1 | rehoboth
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | hobyo
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | padang
# Processing Record 25 of Set 1 | kuching
# Processing Record 26 of Set 1 | kulu
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | manta
# Processing Record 29 of Set 1 | cidreira
# Processing Record 30 of Set 1 | kharitonovo
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | coihaique
# Processing Record 33 of Set 1 | ohara
# Processing Record 34 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | abu dhabi
# Processing Record 40 of Set 1 | alberton
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | turan
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | osorio
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | araouane
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | madoc
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | scarborough
# Processing Record 3 of Set 2 | boca do acre
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | nykobing
# City not found. Skipping...
# Processing Record 6 of Set 2 | bowen
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | faya
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | podgornoye
# Processing Record 12 of Set 2 | ballybofey
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | phangnga
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | riviere-au-renard
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | awjilah
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | maceio
# Processing Record 21 of Set 2 | adrar
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 2 | jinchang
# Processing Record 25 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 2 | sorong
# Processing Record 27 of Set 2 | laizhou
# Processing Record 28 of Set 2 | jorpeland
# Processing Record 29 of Set 2 | palmerston
# Processing Record 30 of Set 2 | imbituba
# Processing Record 31 of Set 2 | udankudi
# Processing Record 32 of Set 2 | kununurra
# Processing Record 33 of Set 2 | onufriyivka
# Processing Record 34 of Set 2 | opuwo
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | aklavik
# Processing Record 38 of Set 2 | devyatka
# City not found. Skipping...
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | evansville
# Processing Record 42 of Set 2 | nandigama
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | golkoy
# Processing Record 46 of Set 2 | puerto escondido
# Processing Record 47 of Set 2 | vilyuysk
# Processing Record 48 of Set 2 | saint-pierre
# Processing Record 49 of Set 2 | batagay
# Processing Record 50 of Set 2 | nueva londres
# Processing Record 1 of Set 3 | sao joao da barra
# Processing Record 2 of Set 3 | dongying
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | port elizabeth
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | ruthin
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 3 | angoram
# Processing Record 11 of Set 3 | abu kamal
# Processing Record 12 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | mayumba
# Processing Record 18 of Set 3 | ushuaia
# Processing Record 19 of Set 3 | marawi
# Processing Record 20 of Set 3 | olafsvik
# Processing Record 21 of Set 3 | pangkalanbuun
# Processing Record 22 of Set 3 | la ronge
# Processing Record 23 of Set 3 | hambantota
# Processing Record 24 of Set 3 | petranka
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | itupiranga
# Processing Record 27 of Set 3 | sai buri
# Processing Record 28 of Set 3 | malakal
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | sayanogorsk
# Processing Record 31 of Set 3 | dryden
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | ipameri
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | leh
# Processing Record 38 of Set 3 | cockburn town
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | wanning
# Processing Record 41 of Set 3 | narsaq
# Processing Record 42 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 44 of Set 3 | bethanien
# Processing Record 45 of Set 3 | dogondoutchi
# Processing Record 46 of Set 3 | barcelona
# Processing Record 47 of Set 3 | albany
# Processing Record 48 of Set 3 | knysna
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | bethel
# Processing Record 2 of Set 4 | perivolion
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | sisimiut
# Processing Record 5 of Set 4 | lasem
# Processing Record 6 of Set 4 | shakawe
# Processing Record 7 of Set 4 | ubatuba
# Processing Record 8 of Set 4 | shimoda
# Processing Record 9 of Set 4 | a
# City not found. Skipping...
# Processing Record 10 of Set 4 | terney
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | shitanjing
# Processing Record 13 of Set 4 | georgiyevka
# Processing Record 14 of Set 4 | mindelo
# Processing Record 15 of Set 4 | saquarema
# Processing Record 16 of Set 4 | rantepao
# Processing Record 17 of Set 4 | altamira
# Processing Record 18 of Set 4 | port moresby
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | yulara
# Processing Record 21 of Set 4 | harrismith
# Processing Record 22 of Set 4 | kibala
# Processing Record 23 of Set 4 | varzea da palma
# Processing Record 24 of Set 4 | bilibino
# Processing Record 25 of Set 4 | ballaghaderreen
# Processing Record 26 of Set 4 | aripuana
# Processing Record 27 of Set 4 | hami
# Processing Record 28 of Set 4 | flin flon
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | narrabri
# Processing Record 31 of Set 4 | kifri
# Processing Record 32 of Set 4 | kaseda
# Processing Record 33 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 4 | mount gambier
# Processing Record 35 of Set 4 | voznesenskoye
# Processing Record 36 of Set 4 | dalby
# Processing Record 37 of Set 4 | voh
# Processing Record 38 of Set 4 | praia da vitoria
# Processing Record 39 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 4 | namatanai
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | makaha
# Processing Record 43 of Set 4 | harper
# Processing Record 44 of Set 4 | poum
# Processing Record 45 of Set 4 | arlit
# Processing Record 46 of Set 4 | flinders
# Processing Record 47 of Set 4 | roald
# Processing Record 48 of Set 4 | margate
# Processing Record 49 of Set 4 | samarai
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | benin
# Processing Record 2 of Set 5 | kangaatsiaq
# Processing Record 3 of Set 5 | tazovskiy
# Processing Record 4 of Set 5 | aylmer
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 5 | arman
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | lazaro cardenas
# Processing Record 10 of Set 5 | qasigiannguit
# Processing Record 11 of Set 5 | nishihara
# Processing Record 12 of Set 5 | diamantino
# Processing Record 13 of Set 5 | yar-sale
# Processing Record 14 of Set 5 | plettenberg bay
# Processing Record 15 of Set 5 | kenora
# Processing Record 16 of Set 5 | pasinler
# Processing Record 17 of Set 5 | russell
# Processing Record 18 of Set 5 | touros
# Processing Record 19 of Set 5 | nikolskoye
# Processing Record 20 of Set 5 | atar
# Processing Record 21 of Set 5 | oktyabrskiy
# Processing Record 22 of Set 5 | harer
# Processing Record 23 of Set 5 | qaqortoq
# Processing Record 24 of Set 5 | palmer
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | oistins
# Processing Record 27 of Set 5 | mayo
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | churapcha
# Processing Record 30 of Set 5 | ukiah
# Processing Record 31 of Set 5 | oga
# Processing Record 32 of Set 5 | matara
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | honavar
# Processing Record 35 of Set 5 | ruidoso
# Processing Record 36 of Set 5 | newport
# Processing Record 37 of Set 5 | twentynine palms
# Processing Record 38 of Set 5 | deputatskiy
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | haines junction
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | muros
# Processing Record 43 of Set 5 | castro
# Processing Record 44 of Set 5 | minab
# Processing Record 45 of Set 5 | zabol
# Processing Record 46 of Set 5 | gizo
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | eyrarbakki
# Processing Record 49 of Set 5 | ishigaki
# Processing Record 50 of Set 5 | ambilobe
# Processing Record 1 of Set 6 | berlevag
# Processing Record 2 of Set 6 | nelas
# Processing Record 3 of Set 6 | siparia
# Processing Record 4 of Set 6 | manuk mangkaw
# Processing Record 5 of Set 6 | mamou
# Processing Record 6 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 7 of Set 6 | zhigansk
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | ketchikan
# Processing Record 10 of Set 6 | san carlos de bariloche
# Processing Record 11 of Set 6 | baykit
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | bambous virieux
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | matthews
# Processing Record 16 of Set 6 | mastic beach
# Processing Record 17 of Set 6 | manzhouli
# Processing Record 18 of Set 6 | itoman
# Processing Record 19 of Set 6 | sena madureira
# Processing Record 20 of Set 6 | luderitz
# Processing Record 21 of Set 6 | dingle
# Processing Record 22 of Set 6 | komsomolskiy
# Processing Record 23 of Set 6 | bo
# City not found. Skipping...
# Processing Record 24 of Set 6 | kloulklubed
# Processing Record 25 of Set 6 | college
# Processing Record 26 of Set 6 | ushibuka
# Processing Record 27 of Set 6 | avera
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | goderich
# Processing Record 30 of Set 6 | daru
# Processing Record 31 of Set 6 | klaksvik
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | raymondville
# Processing Record 34 of Set 6 | buzuluk
# Processing Record 35 of Set 6 | magistralnyy
# Processing Record 36 of Set 6 | labuhan
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | uhlove
# Processing Record 39 of Set 6 | iguape
# Processing Record 40 of Set 6 | namibe
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | lixourion
# Processing Record 43 of Set 6 | savannah bight
# Processing Record 44 of Set 6 | ponta do sol
# Processing Record 45 of Set 6 | srednekolymsk
# Processing Record 46 of Set 6 | ilulissat
# Processing Record 47 of Set 6 | constitucion
# Processing Record 48 of Set 6 | presidencia roque saenz pena
# Processing Record 49 of Set 6 | christchurch
# Processing Record 50 of Set 6 | la guardia
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | yaan
# Processing Record 3 of Set 7 | grande riviere du nord
# Processing Record 4 of Set 7 | assela
# City not found. Skipping...
# Processing Record 5 of Set 7 | malkangiri
# Processing Record 6 of Set 7 | broken hill
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 7 | caceres
# Processing Record 11 of Set 7 | zheleznodorozhnyy
# Processing Record 12 of Set 7 | wawa
# Processing Record 13 of Set 7 | vestmannaeyjar
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | khatanga
# Processing Record 16 of Set 7 | atka
# City not found. Skipping...
# Processing Record 17 of Set 7 | chuy
# Processing Record 18 of Set 7 | nianzishan
# Processing Record 19 of Set 7 | dawei
# Processing Record 20 of Set 7 | charters towers
# Processing Record 21 of Set 7 | alekseyevka
# Processing Record 22 of Set 7 | sept-iles
# Processing Record 23 of Set 7 | guerrero negro
# Processing Record 24 of Set 7 | slobozia-ciorasti
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | ampanihy
# Processing Record 27 of Set 7 | acajutla
# Processing Record 28 of Set 7 | leningradskiy
# Processing Record 29 of Set 7 | palo
# Processing Record 30 of Set 7 | cleveland
# Processing Record 31 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 7 | sosnovo-ozerskoye
# Processing Record 33 of Set 7 | geraldton
# Processing Record 34 of Set 7 | tyrma
# Processing Record 35 of Set 7 | kamenskiy
# Processing Record 36 of Set 7 | bayji
# Processing Record 37 of Set 7 | almaznyy
# Processing Record 38 of Set 7 | jinji
# Processing Record 39 of Set 7 | northam
# Processing Record 40 of Set 7 | ganzhou
# Processing Record 41 of Set 7 | manzil tamim
# City not found. Skipping...
# Processing Record 42 of Set 7 | paoua
# Processing Record 43 of Set 7 | le port
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | rawson
# Processing Record 46 of Set 7 | tyukhtet
# Processing Record 47 of Set 7 | lumsden
# Processing Record 48 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | gambo
# Processing Record 50 of Set 7 | narkanda
# Processing Record 1 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 2 of Set 8 | saint george
# Processing Record 3 of Set 8 | aksarka
# Processing Record 4 of Set 8 | tapes
# Processing Record 5 of Set 8 | strelka
# Processing Record 6 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 8 | oranjemund
# Processing Record 8 of Set 8 | mandalgovi
# Processing Record 9 of Set 8 | chapais
# Processing Record 10 of Set 8 | kasongo
# Processing Record 11 of Set 8 | rognan
# Processing Record 12 of Set 8 | upata
# Processing Record 13 of Set 8 | tautira
# Processing Record 14 of Set 8 | hanover
# Processing Record 15 of Set 8 | roseburg
# Processing Record 16 of Set 8 | camana
# Processing Record 17 of Set 8 | tayoltita
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 8 | bobon
# Processing Record 21 of Set 8 | chumikan
# Processing Record 22 of Set 8 | limbang
# Processing Record 23 of Set 8 | lavrentiya
# Processing Record 24 of Set 8 | cabedelo
# Processing Record 25 of Set 8 | zhuhai
# Processing Record 26 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 8 | vardo
# Processing Record 28 of Set 8 | nara
# Processing Record 29 of Set 8 | yoichi
# Processing Record 30 of Set 8 | cotonou
# Processing Record 31 of Set 8 | manambrag
# City not found. Skipping...
# Processing Record 32 of Set 8 | vengerovo
# Processing Record 33 of Set 8 | mbandaka
# Processing Record 34 of Set 8 | zaykovo
# Processing Record 35 of Set 8 | lichinga
# Processing Record 36 of Set 8 | sari
# Processing Record 37 of Set 8 | labytnangi
# Processing Record 38 of Set 8 | calabozo
# Processing Record 39 of Set 8 | kelvington
# Processing Record 40 of Set 8 | trofors
# Processing Record 41 of Set 8 | abalak
# Processing Record 42 of Set 8 | pangnirtung
# Processing Record 43 of Set 8 | porto belo
# Processing Record 44 of Set 8 | seddon
# Processing Record 45 of Set 8 | kovdor
# Processing Record 46 of Set 8 | nanortalik
# Processing Record 47 of Set 8 | colares
# Processing Record 48 of Set 8 | viedma
# Processing Record 49 of Set 8 | ural
# Processing Record 50 of Set 8 | progreso
# Processing Record 1 of Set 9 | kruisfontein
# Processing Record 2 of Set 9 | yurkivka
# Processing Record 3 of Set 9 | guilin
# Processing Record 4 of Set 9 | grindavik
# Processing Record 5 of Set 9 | onega
# Processing Record 6 of Set 9 | viet tri
# Processing Record 7 of Set 9 | rocha
# Processing Record 8 of Set 9 | bucerias
# Processing Record 9 of Set 9 | saint-francois
# Processing Record 10 of Set 9 | san luis
# Processing Record 11 of Set 9 | gat
# Processing Record 12 of Set 9 | eston
# Processing Record 13 of Set 9 | emmett
# Processing Record 14 of Set 9 | vrangel
# Processing Record 15 of Set 9 | rindal
# Processing Record 16 of Set 9 | byron bay
# Processing Record 17 of Set 9 | virginia beach
# Processing Record 18 of Set 9 | bacoor
# Processing Record 19 of Set 9 | novikovo
# Processing Record 20 of Set 9 | sinjar
# Processing Record 21 of Set 9 | vila
# Processing Record 22 of Set 9 | baherden
# Processing Record 23 of Set 9 | urbana
# Processing Record 24 of Set 9 | celestun
# Processing Record 25 of Set 9 | walvis bay
# Processing Record 26 of Set 9 | viseu
# Processing Record 27 of Set 9 | wenling
# Processing Record 28 of Set 9 | meulaboh
# Processing Record 29 of Set 9 | tomakomai
# Processing Record 30 of Set 9 | fereydunshahr
# Processing Record 31 of Set 9 | sasovo
# Processing Record 32 of Set 9 | wewak
# Processing Record 33 of Set 9 | pacific grove
# Processing Record 34 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 9 | chicama
# Processing Record 36 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 9 | palafrugell
# Processing Record 38 of Set 9 | carballo
# Processing Record 39 of Set 9 | sirnak
# Processing Record 40 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 9 | at-bashi
# Processing Record 42 of Set 9 | sulangan
# Processing Record 43 of Set 9 | tibagi
# Processing Record 44 of Set 9 | kutum
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | xining
# Processing Record 48 of Set 9 | winchester
# Processing Record 49 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 9 | turtas
# Processing Record 1 of Set 10 | nanning
# Processing Record 2 of Set 10 | ust-barguzin
# Processing Record 3 of Set 10 | ostersund
# Processing Record 4 of Set 10 | druzhba
# Processing Record 5 of Set 10 | tamiahua
# Processing Record 6 of Set 10 | shellbrook
# Processing Record 7 of Set 10 | nalut
# Processing Record 8 of Set 10 | sorland
# Processing Record 9 of Set 10 | roma
# Processing Record 10 of Set 10 | rossland
# Processing Record 11 of Set 10 | pali
# Processing Record 12 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 10 | laiwu
# Processing Record 14 of Set 10 | cozumel
# Processing Record 15 of Set 10 | celina
# Processing Record 16 of Set 10 | pimentel
# Processing Record 17 of Set 10 | bac lieu
# Processing Record 18 of Set 10 | san patricio
# Processing Record 19 of Set 10 | mana
# Processing Record 20 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 21 of Set 10 | kimberley
# Processing Record 22 of Set 10 | kavieng
# Processing Record 23 of Set 10 | nyurba
# Processing Record 24 of Set 10 | banjar
# Processing Record 25 of Set 10 | port jervis
# Processing Record 26 of Set 10 | kpandu
# Processing Record 27 of Set 10 | belmonte
# Processing Record 28 of Set 10 | svetlogorsk
# Processing Record 29 of Set 10 | comodoro rivadavia
# Processing Record 30 of Set 10 | srandakan
# Processing Record 31 of Set 10 | praya
# Processing Record 32 of Set 10 | sinnamary
# Processing Record 33 of Set 10 | atherton
# Processing Record 34 of Set 10 | novoukrayinka
# Processing Record 35 of Set 10 | morehead
# Processing Record 36 of Set 10 | ust-nera
# Processing Record 37 of Set 10 | alpena
# Processing Record 38 of Set 10 | kabinda
# Processing Record 39 of Set 10 | ingham
# Processing Record 40 of Set 10 | aksay
# Processing Record 41 of Set 10 | ulaanbaatar
# Processing Record 42 of Set 10 | yuzhno-kurilsk
# Processing Record 43 of Set 10 | salalah
# Processing Record 44 of Set 10 | qui nhon
# Processing Record 45 of Set 10 | quetta
# Processing Record 46 of Set 10 | new waterford
# Processing Record 47 of Set 10 | usinsk
# Processing Record 48 of Set 10 | sindor
# Processing Record 49 of Set 10 | vostochnyy
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | juneau
# Processing Record 2 of Set 11 | vanimo
# Processing Record 3 of Set 11 | grand gaube
# Processing Record 4 of Set 11 | springbok
# Processing Record 5 of Set 11 | batemans bay
# Processing Record 6 of Set 11 | bosaso
# Processing Record 7 of Set 11 | erie
# Processing Record 8 of Set 11 | roblin
# Processing Record 9 of Set 11 | nicoya
# Processing Record 10 of Set 11 | oktyabrskoye
# Processing Record 11 of Set 11 | susanville
# Processing Record 12 of Set 11 | la libertad
# Processing Record 13 of Set 11 | alice springs
# Processing Record 14 of Set 11 | westport
# Processing Record 15 of Set 11 | torbat-e jam
# Processing Record 16 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 11 | uruacu
# Processing Record 18 of Set 11 | hamilton
# Processing Record 19 of Set 11 | kunnamangalam
# Processing Record 20 of Set 11 | ciudad bolivar
# Processing Record 21 of Set 11 | kurilsk
# Processing Record 22 of Set 11 | kodiak
# Processing Record 23 of Set 11 | acapulco
# Processing Record 24 of Set 11 | redmond
# Processing Record 25 of Set 11 | melbu
# Processing Record 26 of Set 11 | jizan
# Processing Record 27 of Set 11 | meadow lake
# Processing Record 28 of Set 11 | pailon
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | sidmouth
# Processing Record 31 of Set 11 | jiuquan
# Processing Record 32 of Set 11 | fenoarivo
# Processing Record 33 of Set 11 | matata
# Processing Record 34 of Set 11 | la tuque
# Processing Record 35 of Set 11 | portland
# Processing Record 36 of Set 11 | zalantun
# Processing Record 37 of Set 11 | kokoda
# Processing Record 38 of Set 11 | mlonggo
# Processing Record 39 of Set 11 | puerto leguizamo
# Processing Record 40 of Set 11 | puerto narino
# Processing Record 41 of Set 11 | ucluelet
# Processing Record 42 of Set 11 | boende
# Processing Record 43 of Set 11 | antofagasta
# Processing Record 44 of Set 11 | mazyr
# Processing Record 45 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 46 of Set 11 | zhanaozen
# Processing Record 47 of Set 11 | cordele
# Processing Record 48 of Set 11 | maragogi
# Processing Record 49 of Set 11 | merritt island
# Processing Record 50 of Set 11 | ponta delgada
# Processing Record 1 of Set 12 | guayaramerin
# Processing Record 2 of Set 12 | winston-salem
# Processing Record 3 of Set 12 | novovasylivka
# Processing Record 4 of Set 12 | mantua
# Processing Record 5 of Set 12 | raudeberg
# Processing Record 6 of Set 12 | santa rosa
# Processing Record 7 of Set 12 | ulladulla
# Processing Record 8 of Set 12 | bandarbeyla
# Processing Record 9 of Set 12 | vitim
# Processing Record 10 of Set 12 | ocean city
# Processing Record 11 of Set 12 | honiara
# Processing Record 12 of Set 12 | rovaniemi
# Processing Record 13 of Set 12 | languyan
# Processing Record 14 of Set 12 | rhede
# Processing Record 15 of Set 12 | kirakira
# Processing Record 16 of Set 12 | itarema
# Processing Record 17 of Set 12 | stornoway
# Processing Record 18 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 12 | monte santo
# Processing Record 20 of Set 12 | launceston
# Processing Record 21 of Set 12 | mumford
# Processing Record 22 of Set 12 | mtwara
# Processing Record 23 of Set 12 | sitka
# Processing Record 24 of Set 12 | saveh
# Processing Record 25 of Set 12 | malangali
# Processing Record 26 of Set 12 | gangakher
# Processing Record 27 of Set 12 | zaraysk
# Processing Record 28 of Set 12 | scalea
# Processing Record 29 of Set 12 | urucara
# Processing Record 30 of Set 12 | udachnyy
# Processing Record 31 of Set 12 | henties bay
# Processing Record 32 of Set 12 | luebo
# Processing Record 33 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 12 | green river
# Processing Record 35 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 12 | yanam
# Processing Record 37 of Set 12 | saraland
# Processing Record 38 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 12 | vesele
# Processing Record 40 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 12 | gua musang
# Processing Record 42 of Set 12 | aracati
# Processing Record 43 of Set 12 | masvingo
# Processing Record 44 of Set 12 | morros
# Processing Record 45 of Set 12 | callaguip
# Processing Record 46 of Set 12 | leshukonskoye
# Processing Record 47 of Set 12 | sola
# Processing Record 48 of Set 12 | mezen
# Processing Record 49 of Set 12 | rafai
# Processing Record 50 of Set 12 | galitsy
# Processing Record 1 of Set 13 | xinmin
# Processing Record 2 of Set 13 | donskoy
# Processing Record 3 of Set 13 | pecos
# Processing Record 4 of Set 13 | khandyga
# Processing Record 5 of Set 13 | ayan
# Processing Record 6 of Set 13 | nautla
# Processing Record 7 of Set 13 | katobu
# Processing Record 8 of Set 13 | egvekinot
# Processing Record 9 of Set 13 | tubuala
# Processing Record 10 of Set 13 | saint anthony
# Processing Record 11 of Set 13 | havoysund
# Processing Record 12 of Set 13 | ixtapa
# Processing Record 13 of Set 13 | vikhorevka
# Processing Record 14 of Set 13 | popondetta
# Processing Record 15 of Set 13 | salym
# Processing Record 16 of Set 13 | quelimane
# Processing Record 17 of Set 13 | ialibu
# Processing Record 18 of Set 13 | mahanje
# Processing Record 19 of Set 13 | dallas
# Processing Record 20 of Set 13 | karasjok
# Processing Record 21 of Set 13 | kalabo
# Processing Record 22 of Set 13 | vao
# Processing Record 23 of Set 13 | grakhovo
# Processing Record 24 of Set 13 | natal

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5592\1568948798.py in <module>
#       1 # Export the City_Data into a csv
# ----> 2 city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
#
# AttributeError: 'str' object has no attribute 'to_csv'

# %%
# Read saved data
city_data_df = pd.DataFrame(city_data)

# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     66.45        53          33
# 1     Tuatapere -46.1333  167.6833     62.94        64          51
# 2        Hobart -42.8794  147.3294     82.22        53          75
# 3  Longyearbyen  78.2186   15.6401     22.84        68          75
# 4        Atuona  -9.8000 -139.0333     78.49        78          13
#
#    Wind Speed Country                 Date
# 0        7.78      NZ  2023-01-25 06:10:24
# 1        8.08      NZ  2023-01-25 06:10:25
# 2        9.22      AU  2023-01-25 06:10:25
# 3       14.97      SJ  2023-01-25 06:09:28
# 4       17.05      PF  2023-01-25 06:09:31

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/lat_v_maxt.png")

# Show plot.
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plot for latitude vs. humidity.

plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/lat_v_hum.png")

# Show plot.
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/lat_v_cloud.png")

# Show plot.
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plot for latitude vs. wind speed.

plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/lat_v_wind.png")

# Show plot.
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
#Import linear
from scipy.stats import linregress
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

    
#Create dataFrame

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Northern Hemisphere \n for Maximum Temperature", 'Max Temp',(10,40))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Southern Hemisphere \n for Maximum Temperature", 'Max Temp',(-25,40))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# title = "Linear Regression on the Northern Hemisphere \n for % Humidity"
# Call the function.
plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Northern Hemisphere \n for % Humidity", '% Humidity',(45,5))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# title = "Linear Regression on the Northern Hemisphere \n for % Humidity"
# Call the function.
plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Southern Hemisphere \n for % Humidity", '% Humidity',(-55,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(20,30))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,25))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
It shows that the correlation latitude and wind speed is very low. the r-value is less than 0.05 for the north and less than -0.2. It shows on the plots shown for the S. Hemisphere
Which can mean that the speed of wind is not predictable due to the weather changing.
